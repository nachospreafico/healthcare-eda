# %% [markdown]
# # Healthcare Encounters - Exploratory Data Analysis
#
# ## Objective
#
# This notebook performs an exploratory data analysis (EDA) of a synthetic healthcare encounters dataset.
#
# ### Workflow
# 1. Data Loading
# 2. Dataset Overview
# 3. Data Quality Assessment
# 4. Descriptive Statistics
# 5. Categorical Analysis
# 6. Time-based Analysis
# 7. Cross-tabulations
# 8. Key Findings

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## Data Loading
# Load the dataset and required libraries.

# %%
# Read csv into pandas DataFrame

root_path = "../data"
file_name = "healthcare_encounters_eda"

df = pd.read_csv(f"{root_path}/{file_name}.csv")

# %%
# Get number of rows and cols using df.shape

rows, cols = df.shape

print(f"There are {rows} rows and {cols} columns in the dataset")
# Out:
# There are 75000 rows and 15 columns in the dataset

# %% [markdown]
# ## Dataset Overview
# Inspect the dataset structure and a sample of records.

# %%
# Display 5 first rows of the dataset
df.head()
# Out:
#   encounter_id  patient_id admission_date discharge_date   age  gender  \
# 0  ENC-0024295      108983     2025-11-30     2025-12-02  46.0    Male
# 1  ENC-0028410      125400     2024-11-20     2024-11-22  54.0    Male
# 2  ENC-0071214      107225     2024-06-16     2024-06-21  61.0  Female
# 3  ENC-0051899      103487     2024-02-20     2024-02-22  61.0    Male
# 4  ENC-0025778      127610     2024-12-03     2024-12-09  41.0    Male
#
#            region        facility_type diagnosis_category admission_type  \
# 0  Basque Country  University Hospital        Respiratory         Urgent
# 1          Madrid    Specialist Clinic     Cardiovascular    Observation
# 2          Madrid   Community Hospital     Cardiovascular     Emergency
# 3          Madrid   Community Hospital    Musculoskeletal       Elective
# 4       Catalonia    Specialist Clinic     Cardiovascular         Urgent
#
#    length_of_stay_days  total_cost_eur insurance_type readmitted_30d  \
# 0                    2         3948.04        Private             No
# 1                    2         4195.62         Public             No
# 2                    5        13152.90         Public            Yes
# 3                    2         5697.77         Public             No
# 4                    6         5547.88        Private             No
#
#    patient_satisfaction_score
# 0                         7.9
# 1                         7.1
# 2                         8.3
# 3                         9.0
# 4                         7.7

# %%
# Display 5 last rows of the dataset
df.tail()
# Out:
#       encounter_id  patient_id admission_date discharge_date   age  gender  \
# 74995  ENC-0033292      122016     2025-03-15     2025-03-23  67.0    Male
# 74996  ENC-0039746      102769     2025-03-14     2025-03-22  96.0  Female
# 74997  ENC-0004331      112226     2025-03-16     2025-03-16  61.0  Female
# 74998  ENC-0073240      122344     2024-06-14     2024-06-18  72.0  Female
# 74999  ENC-0009576      119522     2024-12-09     2024-12-14   NaN    Male
#
#           region        facility_type diagnosis_category admission_type  \
# 74995  Catalonia  University Hospital        Respiratory       Elective
# 74996     Madrid   Community Hospital          Endocrine         Urgent
# 74997     Madrid     General Hospital          Endocrine       Elective
# 74998  Andalusia  University Hospital          Endocrine         Urgent
# 74999    Galicia  University Hospital    Musculoskeletal    Observation
#
#        length_of_stay_days  total_cost_eur insurance_type readmitted_30d  \
# 74995                    8         6143.99         Public             No
# 74996                    8         5232.81         Public            Yes
# 74997                    0         2787.54         Public             No
# 74998                    4         5400.68         Public             No
# 74999                    5        98044.87         Public             No
#
#        patient_satisfaction_score
# 74995                         8.7
# 74996                         9.4
# 74997                         6.8
# 74998                         8.3
# 74999                         4.6

# %%
# Display 5 random rows of the dataset
df.sample(n=5)
# Out:
#       encounter_id  patient_id admission_date discharge_date   age  \
# 67179  ENC-0001314      109222     2024-12-17     2024-12-22  49.0
# 10867  ENC-0032371      116027     2024-03-06     2024-03-07  26.0
# 62107  ENC-0030609      115217     2024-05-07     2024-05-21  83.0
# 51815  ENC-0064933      104177     2024-10-27     2024-10-28  43.0
# 15929  ENC-0006076      130450     2024-02-03     2024-02-06  62.0
#
#            gender          region        facility_type diagnosis_category  \
# 67179      Female       Andalusia  University Hospital    Musculoskeletal
# 10867        Male       Catalonia   Community Hospital          Endocrine
# 62107      Female       Catalonia   Community Hospital              Renal
# 51815      Female  Basque Country     General Hospital      Mental Health
# 15929  Non-binary       Catalonia  University Hospital          Endocrine
#
#       admission_type  length_of_stay_days  total_cost_eur insurance_type  \
# 67179         Urgent                    5         8252.86         Public
# 10867    Observation                    1         2916.51         Public
# 62107      Emergency                   14        11465.52         Public
# 51815       Elective                    1         2229.57         Public
# 15929    Observation                    3         4796.09       Self-pay
#
#       readmitted_30d  patient_satisfaction_score
# 67179             No                         8.7
# 10867            Yes                         9.6
# 62107             No                         4.9
# 51815             No                         8.3
# 15929             No                         9.4

# %% [markdown]
# ## Data Quality Assessment
# Evaluate completeness, duplicates and data types before analysis.

# %%
# Display column names, their data types and count of non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   encounter_id                75000 non-null  object
#  1   patient_id                  75000 non-null  int64
#  2   admission_date              75000 non-null  object
#  3   discharge_date              74609 non-null  object
#  4   age                         74237 non-null  float64
#  5   gender                      74569 non-null  object
#  6   region                      74485 non-null  object
#  7   facility_type               75000 non-null  object
#  8   diagnosis_category          74373 non-null  object
#  9   admission_type              75000 non-null  object
#  10  length_of_stay_days         75000 non-null  int64
#  11  total_cost_eur              75000 non-null  float64
#  12  insurance_type              74458 non-null  object
#  13  readmitted_30d              75000 non-null  object
#  14  patient_satisfaction_score  73713 non-null  float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 8.6+ MB

# %%
# Create a table showing every column and the number of missing values in that column, sorted from highest to lowest
missing_values_table = df.isna().sum().sort_values(ascending=False).to_frame(name="missing_values")
missing_values_table
# Out:
#                             missing_values
# patient_satisfaction_score            1287
# age                                    763
# diagnosis_category                     627
# insurance_type                         542
# region                                 515
# gender                                 431
# discharge_date                         391
# encounter_id                             0
# patient_id                               0
# admission_date                           0
# facility_type                            0
# admission_type                           0
# length_of_stay_days                      0
# total_cost_eur                           0
# readmitted_30d                           0

# %%
# Extend the missing_values_table with the missing values percentage
missing_values_table["missing_percentage"] = round((missing_values_table["missing_values"] / len(df)) * 100, 1)
missing_values_table
# Out:
#                             missing_values  missing_percentage
# patient_satisfaction_score            1287                 1.7
# age                                    763                 1.0
# diagnosis_category                     627                 0.8
# insurance_type                         542                 0.7
# region                                 515                 0.7
# gender                                 431                 0.6
# discharge_date                         391                 0.5
# encounter_id                             0                 0.0
# patient_id                               0                 0.0
# admission_date                           0                 0.0
# facility_type                            0                 0.0
# admission_type                           0                 0.0
# length_of_stay_days                      0                 0.0
# total_cost_eur                           0                 0.0
# readmitted_30d                           0                 0.0

# %%
# Create a table of columns which have 1 or more missin values and their missin values count
cols_with_missing_values = missing_values_table[missing_values_table["missing_values"] > 0]["missing_values"]
cols_with_missing_values
# Out:
# patient_satisfaction_score    1287
# age                            763
# diagnosis_category             627
# insurance_type                 542
# region                         515
# gender                         431
# discharge_date                 391
# Name: missing_values, dtype: int64

# %%
# Display number of duplicated rows in the dataset
duplicated_rows_count = df.duplicated().sum()
print(f"There are {duplicated_rows_count} duplicated rows in the dataset")
# Out:
# There are 600 duplicated rows in the dataset

# %%
# Display all duplicated rows
df[df.duplicated(keep=False)]
# Out:
#       encounter_id  patient_id admission_date discharge_date   age  gender  \
# 104    ENC-0040634      125577     2024-02-12     2024-02-17  35.0  Female
# 184    ENC-0052060      107267     2025-04-17     2025-04-25  38.0    Male
# 217    ENC-0011060      102359     2024-02-17     2024-02-18  68.0  Female
# 248    ENC-0065842      114006     2024-03-06     2024-03-08  81.0    Male
# 321    ENC-0054580      114355     2025-01-24     2025-01-28  58.0  Female
# ...            ...         ...            ...            ...   ...     ...
# 74353  ENC-0028921      103077     2025-02-07     2025-02-09  64.0  Female
# 74381  ENC-0068222      131026     2025-01-20     2025-01-21  43.0    Male
# 74485  ENC-0007635      101828     2024-03-20     2024-03-30  50.0  Female
# 74632  ENC-0068465      112973     2024-09-03     2024-09-11  47.0    Male
# 74806  ENC-0024618      120702     2025-10-07     2025-10-19  58.0    Male
#
#                region        facility_type  diagnosis_category admission_type  \
# 104            Madrid     General Hospital       Mental Health       Elective
# 184         Andalusia  University Hospital  Infectious Disease      Emergency
# 217    Basque Country   Community Hospital    Gastrointestinal      Emergency
# 248            Madrid    Specialist Clinic    Gastrointestinal       Elective
# 321           Galicia     General Hospital         Respiratory       Elective
# ...               ...                  ...                 ...            ...
# 74353       Catalonia    Specialist Clinic      Cardiovascular         Urgent
# 74381          Madrid   Community Hospital        Neurological       Elective
# 74485        Valencia   Community Hospital               Renal       Elective
# 74632        Valencia     General Hospital        Neurological         Urgent
# 74806        Valencia   Community Hospital           Endocrine         Urgent
#
#        length_of_stay_days  total_cost_eur insurance_type readmitted_30d  \
# 104                      5         8089.83         Public             No
# 184                      8         6279.46         Public             No
# 217                      1         3529.80        Private            Yes
# 248                      2         3679.67         Public             No
# 321                      4         4118.01       Self-pay             No
# ...                    ...             ...            ...            ...
# 74353                    2         5368.21         Public             No
# 74381                    1         7889.64        Private             No
# 74485                   10        13032.31         Public             No
# 74632                    8        11155.37         Public             No
# 74806                   12         6104.49         Public             No
#
#        patient_satisfaction_score
# 104                           7.4
# 184                           7.5
# 217                           8.5
# 248                          10.0
# 321                           6.3
# ...                           ...
# 74353                         7.1
# 74381                         6.7
# 74485                         6.6
# 74632                         6.3
# 74806                         7.1
#
# [1200 rows x 15 columns]

# %% [markdown]
# ## Descriptive Statistics
# Summarize numerical and categorical variables.

# %%
# Create a table of gender distribution with frequency and percentage, keeping null values
gender_distribution = (
    df["gender"]
    .value_counts(dropna=False)
    .to_frame(name="frequency")
)

gender_distribution["percentage"] = (
    gender_distribution["frequency"] / len(df) * 100
).round(1)

gender_distribution
# Out:
#               frequency  percentage
# gender
# Female            37443        49.9
# Male              36314        48.4
# Non-binary          500         0.7
# NaN                 431         0.6
# MALE                 60         0.1
#  Female              60         0.1
#  Male                54         0.1
# FEMALE               47         0.1
# male                 46         0.1
# female               44         0.1
#  Non-binary           1         0.0

# %%
# Create a summary statistic table for all numeric columns
numeric_statistics = df.select_dtypes(include="number").describe().round(2)
numeric_statistics
# Out:
#        patient_id       age  length_of_stay_days  total_cost_eur  \
# count    75000.00  74237.00             75000.00        75000.00
# mean    115975.11     53.19                 4.88         7075.10
# std       9251.71     20.02                 4.22         4617.49
# min     100001.00     -3.00                 0.00         -250.00
# 25%     107999.75     40.00                 2.00         4389.78
# 50%     115920.50     54.00                 4.00         6082.18
# 75%     123986.00     67.00                 6.00         8582.62
# max     132000.00    132.00               119.00       262883.43
#
#        patient_satisfaction_score
# count                    73713.00
# mean                         7.72
# std                          1.22
# min                          0.00
# 25%                          6.90
# 50%                          7.80
# 75%                          8.60
# max                         12.00

# %%
# Create a summary statistic table for all numeric columns
categorical_summary = (
    df.select_dtypes(include="object")
      .describe(include="all")
      .T[["unique", "top", "freq"]]
      .rename(columns={"unique": "n_unique"})
)
categorical_summary
# Out:
#                    n_unique               top   freq
# encounter_id          74400       ENC-0073782      2
# admission_date          731        2025-11-14    139
# discharge_date          753        2025-09-23    137
# gender                   10            Female  37443
# region                   30         Catalonia  18604
# facility_type             4  General Hospital  32146
# diagnosis_category       10       Respiratory  11865
# admission_type           16         Emergency  31400
# insurance_type           15            Public  45886
# readmitted_30d            2                No  62986

# %%
# Get encounter_id, patient_id and total_cost_eur of 10 most expensive hospital encounters
df.nlargest(
    10,
    "total_cost_eur"
)[["encounter_id", "patient_id", "total_cost_eur"]]
# Out:
#       encounter_id  patient_id  total_cost_eur
# 66375  ENC-0061085      107139       262883.43
# 20133  ENC-0063845      114650       257449.88
# 12252  ENC-0057349      131335       241378.67
# 7585   ENC-0057092      111001       206886.43
# 27212  ENC-0041741      120253       166868.52
# 18785  ENC-0028417      102898       149640.73
# 71436  ENC-0070863      121093       138028.48
# 15192  ENC-0038059      104219       120605.16
# 21895  ENC-0054685      120356       119445.40
# 44165  ENC-0066469      128104       110001.24

# %%
# Get count of encounters, avg total cost and median total cost for each diagnosis, sorted descending by mean value
df.groupby("diagnosis_category", as_index=False)[["encounter_id", "total_cost_eur"]].agg(
    {
        "encounter_id": "count",
        "total_cost_eur": ["mean", "median"]
    }
).sort_values(by=("total_cost_eur", "mean"), ascending=False)
# Out:
#    diagnosis_category encounter_id total_cost_eur
#                              count           mean    median
# 0      Cardiovascular        10281   10984.491119  9864.650
# 7        Neurological         5978   10356.902683  9271.965
# 8               Renal         4518    8841.332778  8036.735
# 4              Injury         5955    7213.913154  6524.490
# 3  Infectious Disease         5260    6935.398327  6271.385
# 6     Musculoskeletal         9752    6271.681955  5735.490
# 9         Respiratory        11865    6107.490922  5489.790
# 5       Mental Health         4438    5720.272699  5094.500
# 2    Gastrointestinal         8924    5136.386010  4656.995
# 1           Endocrine         7402    3681.603436  3361.595

# %%
# Convert date columns into proper datetime objects
df["admission_date"] = pd.to_datetime(df["admission_date"])
df["discharge_date"] = pd.to_datetime(df["discharge_date"])

# %% [markdown]
# ## Time-based Analysis
# Explore encounter trends over time.

# %%
df["year_month"] = df["admission_date"].dt.to_period("M")
df.groupby("year_month", as_index=False)["encounter_id"].count().rename(columns={"encounter_id":"admissions_count"})
# Out:
#    year_month  admissions_count
# 0     2024-01              3149
# 1     2024-02              3058
# 2     2024-03              3166
# 3     2024-04              3055
# 4     2024-05              3176
# 5     2024-06              3160
# 6     2024-07              3189
# 7     2024-08              3130
# 8     2024-09              3033
# 9     2024-10              3028
# 10    2024-11              3075
# 11    2024-12              3121
# 12    2025-01              3224
# 13    2025-02              3041
# 14    2025-03              3203
# 15    2025-04              3097
# 16    2025-05              3230
# 17    2025-06              3074
# 18    2025-07              3291
# 19    2025-08              3201
# 20    2025-09              3067
# 21    2025-10              3145
# 22    2025-11              3026
# 23    2025-12              3061

# %%
df.groupby("readmitted_30d", as_index=False)[["encounter_id", "length_of_stay_days"]].agg(
    count_of_admissions=("encounter_id", "count"),
    mean_length_of_stay=("length_of_stay_days", "mean"),
    median_length_of_stay=("length_of_stay_days", "median"),
    std_length_of_stay=("length_of_stay_days", "std")
).sort_values(by="mean_length_of_stay", ascending=False)
# Out:
#   readmitted_30d  count_of_admissions  mean_length_of_stay  \
# 1            Yes                12014             6.334610
# 0             No                62986             4.600403
#
#    median_length_of_stay  std_length_of_stay
# 1                    5.0            5.174382
# 0                    4.0            3.954905

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   encounter_id                75000 non-null  object
#  1   patient_id                  75000 non-null  int64
#  2   admission_date              75000 non-null  datetime64[ns]
#  3   discharge_date              74609 non-null  datetime64[ns]
#  4   age                         74237 non-null  float64
#  5   gender                      74569 non-null  object
#  6   region                      74485 non-null  object
#  7   facility_type               75000 non-null  object
#  8   diagnosis_category          74373 non-null  object
#  9   admission_type              75000 non-null  object
#  10  length_of_stay_days         75000 non-null  int64
#  11  total_cost_eur              75000 non-null  float64
#  12  insurance_type              74458 non-null  object
#  13  readmitted_30d              75000 non-null  object
#  14  patient_satisfaction_score  73713 non-null  float64
#  15  year_month                  75000 non-null  period[M]
# dtypes: datetime64[ns](2), float64(3), int64(2), object(8), period[M](1)
# memory usage: 9.2+ MB

# %% [markdown]
# ## Cross-tabulation Analysis
# Compare encounter volumes across multiple categorical dimensions.

# %%
df.pivot_table(index="facility_type", columns="insurance_type", values="encounter_id", aggfunc="count").fillna(0).astype(int)
# Out:
# insurance_type       EMPLOYER SPONSORED  Employer Sponsored  \
# facility_type
# Community Hospital                    6                1927
# General Hospital                     13                4395
# Specialist Clinic                     2                1386
# University Hospital                   3                2586
#
# insurance_type       Employer Sponsored   PRIVATE  PUBLIC  Private  Private   \
# facility_type
# Community Hospital                     6        9      16     2687         0
# General Hospital                       5        7      29     6127        12
# Specialist Clinic                      3        5      16     1829         5
# University Hospital                    4        4      21     3542         6
#
# insurance_type       Public  Public   SELF-PAY  Self-pay  employer sponsored  \
# facility_type
# Community Hospital     8865       15         1       730                   8
# General Hospital      19634       28         3      1630                   9
# Specialist Clinic      6083        7         0       471                   3
# University Hospital   11304       18         0       900                   4
#
# insurance_type       private  public  self-pay
# facility_type
# Community Hospital         3      15         1
# General Hospital          12      25         6
# Specialist Clinic          3      10         1
# University Hospital        3      13         2

# %%
# For each gender, calculate mean age and mean total cost
df.groupby("gender", as_index=False).agg(
    mean_age=("age", "mean"),
    mean_total_cost_eur=("total_cost_eur", "mean")
).round(1).sort_values(by="mean_total_cost_eur", ascending=False)
# Out:
#          gender  mean_age  mean_total_cost_eur
# 5          MALE      54.7               7714.1
# 9          male      55.1               7248.1
# 6          Male      53.2               7082.9
# 4        Female      53.2               7075.3
# 7    Non-binary      53.0               6970.2
# 0       Female       52.0               6632.8
# 8        female      54.8               6562.1
# 1         Male       49.6               6065.2
# 3        FEMALE      45.5               5860.9
# 2   Non-binary       46.0               4655.1

# %%
# For each patient, return their most recent encounter
(
    df[["patient_id", "encounter_id", "admission_date"]]
    .sort_values(by="admission_date", ascending=False)
    .drop_duplicates(subset=["patient_id"], keep="first")
)
# Out:
#        patient_id encounter_id admission_date
# 70884      114840  ENC-0005720     2025-12-31
# 74143      120515  ENC-0041045     2025-12-31
# 7757       102856  ENC-0004780     2025-12-31
# 71404      119664  ENC-0073068     2025-12-31
# 6817       114563  ENC-0057212     2025-12-31
# ...           ...          ...            ...
# 66826      121906  ENC-0023775     2024-01-01
# 68311      122629  ENC-0001602     2024-01-01
# 24838      128060  ENC-0027790     2024-01-01
# 70304      130400  ENC-0068450     2024-01-01
# 47498      109173  ENC-0041425     2024-01-01
#
# [23234 rows x 3 columns]

# %%
df = df.sort_values(by=["patient_id", "admission_date"])
df["encounter_number"] = (
    df.groupby("patient_id", as_index=False)
    .cumcount() + 1
) 
df.head()
# Out:
#       encounter_id  patient_id admission_date discharge_date   age  gender  \
# 19149  ENC-0013242      100001     2025-08-11     2025-08-12  28.0  Female
# 11373  ENC-0032710      100003     2024-07-30     2024-08-02  51.0    Male
# 27192  ENC-0054756      100003     2025-02-02     2025-02-05  85.0  Female
# 29638  ENC-0023037      100003     2025-05-18     2025-05-29  69.0  Female
# 57873  ENC-0026370      100003     2025-12-24     2025-12-27  19.0    Male
#
#                region        facility_type diagnosis_category admission_type  \
# 19149  Basque Country    Specialist Clinic        Respiratory       Elective
# 11373          Madrid     General Hospital        Respiratory      Emergency
# 27192       Catalonia    Specialist Clinic    Musculoskeletal      Emergency
# 29638          Madrid     General Hospital      Mental Health      Emergency
# 57873          Madrid  University Hospital             Injury      Emergency
#
#        length_of_stay_days  total_cost_eur insurance_type readmitted_30d  \
# 19149                    1         2887.61        Private             No
# 11373                    3         8501.30        Private             No
# 27192                    3         5678.18         Public             No
# 29638                   11         6103.50         Public             No
# 57873                    3         7309.36         Public             No
#
#        patient_satisfaction_score year_month  encounter_number
# 19149                         NaN    2025-08                 1
# 11373                         8.0    2024-07                 1
# 27192                         7.0    2025-02                 2
# 29638                         7.2    2025-05                 3
# 57873                         7.6    2025-12                 4

# %%
df = df.sort_values(["patient_id", "admission_date"])

previous_date = (
    df.groupby("patient_id")["admission_date"]
      .shift()
)

df["days_since_previous"] = (
    (df["admission_date"] - previous_date)
    .dt.days
)

df.head()
# Out:
#       encounter_id  patient_id admission_date discharge_date   age  gender  \
# 19149  ENC-0013242      100001     2025-08-11     2025-08-12  28.0  Female
# 11373  ENC-0032710      100003     2024-07-30     2024-08-02  51.0    Male
# 27192  ENC-0054756      100003     2025-02-02     2025-02-05  85.0  Female
# 29638  ENC-0023037      100003     2025-05-18     2025-05-29  69.0  Female
# 57873  ENC-0026370      100003     2025-12-24     2025-12-27  19.0    Male
#
#                region        facility_type diagnosis_category admission_type  \
# 19149  Basque Country    Specialist Clinic        Respiratory       Elective
# 11373          Madrid     General Hospital        Respiratory      Emergency
# 27192       Catalonia    Specialist Clinic    Musculoskeletal      Emergency
# 29638          Madrid     General Hospital      Mental Health      Emergency
# 57873          Madrid  University Hospital             Injury      Emergency
#
#        length_of_stay_days  total_cost_eur insurance_type readmitted_30d  \
# 19149                    1         2887.61        Private             No
# 11373                    3         8501.30        Private             No
# 27192                    3         5678.18         Public             No
# 29638                   11         6103.50         Public             No
# 57873                    3         7309.36         Public             No
#
#        patient_satisfaction_score year_month  encounter_number  \
# 19149                         NaN    2025-08                 1
# 11373                         8.0    2024-07                 1
# 27192                         7.0    2025-02                 2
# 29638                         7.2    2025-05                 3
# 57873                         7.6    2025-12                 4
#
#        days_since_previous
# 19149                  NaN
# 11373                  NaN
# 27192                187.0
# 29638                105.0
# 57873                220.0

# %%
min_date = (
    df.groupby("patient_id")["admission_date"]
      .transform("min")
)

df["is_first_encounter"] = df["admission_date"] == min_date

df.head()
# Out:
#       encounter_id  patient_id admission_date discharge_date   age  gender  \
# 19149  ENC-0013242      100001     2025-08-11     2025-08-12  28.0  Female
# 11373  ENC-0032710      100003     2024-07-30     2024-08-02  51.0    Male
# 27192  ENC-0054756      100003     2025-02-02     2025-02-05  85.0  Female
# 29638  ENC-0023037      100003     2025-05-18     2025-05-29  69.0  Female
# 57873  ENC-0026370      100003     2025-12-24     2025-12-27  19.0    Male
#
#                region        facility_type diagnosis_category admission_type  \
# 19149  Basque Country    Specialist Clinic        Respiratory       Elective
# 11373          Madrid     General Hospital        Respiratory      Emergency
# 27192       Catalonia    Specialist Clinic    Musculoskeletal      Emergency
# 29638          Madrid     General Hospital      Mental Health      Emergency
# 57873          Madrid  University Hospital             Injury      Emergency
#
#        length_of_stay_days  total_cost_eur insurance_type readmitted_30d  \
# 19149                    1         2887.61        Private             No
# 11373                    3         8501.30        Private             No
# 27192                    3         5678.18         Public             No
# 29638                   11         6103.50         Public             No
# 57873                    3         7309.36         Public             No
#
#        patient_satisfaction_score year_month  encounter_number  \
# 19149                         NaN    2025-08                 1
# 11373                         8.0    2024-07                 1
# 27192                         7.0    2025-02                 2
# 29638                         7.2    2025-05                 3
# 57873                         7.6    2025-12                 4
#
#        days_since_previous  is_first_encounter
# 19149                  NaN                True
# 11373                  NaN                True
# 27192                187.0               False
# 29638                105.0               False
# 57873                220.0               False

# %% [markdown]
# # Key Findings
#
# > Replace these bullets with observations after completing the analysis.
#
# - Dataset loaded successfully and validated.
# - Data quality assessment completed.
# - Missing values and duplicates reviewed.
# - Descriptive statistics generated.
# - Time-based patterns explored.
# - Cross-tabulations created to compare encounter distributions.
#
# ## Next Steps
#
# - Add visualizations (histograms, bar charts, monthly trends).
# - Investigate relationships between demographics, costs and readmissions.
# - Summarize actionable insights for stakeholders.
